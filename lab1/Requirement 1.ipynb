# %%
# Type your full name
student1_full_name = "FatmaZenhom"

# Type your section 1 or 2
student1_section = "2"

# Type your BN
student1_BN = "40"

###########################################
# Type your full name
student2_full_name = "HanaMostafa"

# Type your section 1 or 2
student2_section = "2"

# Type your BN
student2_BN = "61"

# %%
import re
# if you don't have pandas, uncomment the next line
# !pip install pandas
import pandas as pd

# %% [markdown]
# # Task Description
#
# In this task, you will work with text file containing several emails with their body and other information like sender email, date, subject etc...
#
# Dataset Link: https://www.kaggle.com/datasets/rtatman/fraudulent-email-corpus
#
# Download the dataset then rename the text file to: emails_dataset.txt
#
# The goal of this requirement is to process this text file to convert it to a pandas dataframe to be used easily later. First of all, you need open the text file and try to familiarize yourself with it.
#
# Your task will be implementing the TODOs only. Don't write any code out side the TODOs or change other code of this notebook. You will also need to run all the cells in sequence to produce the final output file to be submitted.

# %%
# Let's read the emails text file
f = open(r"emails_dataset.txt", "r",encoding="latin-1").read()
print(type(f))
# Out:
# <class 'str'>

# %% [markdown]
# Now, we have the whole emails in one string. The first thing we need to do is to split this string to a list containing separate emails. To do this you need to discover the text file. You will notice that every email always starts by a fixed pattern. Your task is to discover what this pattern is to split the string on.

# %%
######################### TODO: write the pattern to split the emails on in the raw string below ######################
start_email_pattern = r"(?m)^From r"
#######################################################################################################################

contents = re.split(start_email_pattern, f)
contents.pop(0)
assert len(contents) == 3976, "Your pattern is wrong"+str(len(contents))

# %% [markdown]
# # Information to be collected
#
# Since we now have a list with all emails, we can iterate over them to collect the information we need. Your task will be to implement some functions using Regular Expressions to collect the following information:
# 1. Sender Email
# 2. Sender Name
# 3. Recipient Email
# 4. Recipient Name
# 5. Date
# 6. Subject

# %%
# This function takes a full email (from the contents list)
# and returns both the sender email and name as strings
# To determine this, look at the original text file and answer the following questions
# what is the pattern that start the line containing both sender name and email?
# If you get this whole line, how to capture the email?
# If you get this whole line, how to capture the name?

def senderEmailAndName(email_item):
    ###################### TODO: write regex that can match the whole line containing the sender name and email #########
    sender_name_email_line_regex = r"(?m)^From:.+"
    #####################################################################################################################
    sender = re.search(sender_name_email_line_regex, email_item)

    # This check is in case there is no sender found (We don't know if all emails contain this info)
    if sender is not None:
        print(sender)
        # Since we have the line You need to do the following
        # You can capture the email by using only one regex (only one re.search())
        # To capture the name safely you can write regex that captures all characters from the end of the start line pattern
        # to the pattern the starts the email
        
        ######################### TODO: write regex that captures the email, and the name #############################
        # email regex: this will capture the email exactly
        email_regex = r"(?<=\<).+(?=\>)|[A-Za-z0-9._%+-]+@[A-Za-z0-9._-]+(\.\w+)*" 
        # name regex: this will capture the name besides some characters before and after it that will be removed later
        name_regex = r"(?<=:\s).+(?=\s<)"
        ##############################################################################################################
        s_email = re.search(email_regex, sender.group())
        s_name = re.search(name_regex, sender.group())
    else:
        s_email = None
        s_name = None

    # We need to check as re.search() may return None
    if s_email is not None:
        sender_email = s_email.group()
    else:
        sender_email = None

    # We need to check as re.search() may return None
    if s_name is not None:
        # Since the name is not captured exactly, we need to substitute all unneeded characters
        
        ############################# TODO: write regex to capture characters to be removed #####################
        characters_remove_from_beginning = '^[^\w]+'
        characters_remove_from_end = '[^\w]+$'
        #########################################################################################################
        sender_name = re.sub(characters_remove_from_end, "", re.sub(characters_remove_from_beginning, "", s_name.group()))
    else:
        sender_name = None

    return sender_email, sender_name

# %%
# This function takes a full email (from the contents list)
# and returns both the recipient email and name as strings
# You will do exactly the same thing you did for sender email except for the pattern used to capture the line
# containing the recipient

def recipientEmailAndName(email_item):
    ###################### TODO: write regex that can match the whole line containing the recipient name and email #########
    recipient_name_email_line_regex = r"(?m)^To:.+"
    #####################################################################################################################
    recipient = re.search(recipient_name_email_line_regex, email_item)

    # This check is in case there is no sender found (We don't know if all emails contain this info)
    if recipient is not None:
        # Since we have the line You need to do the following
        # You can capture the email by using only one regex (only one re.search())
        # To capture the name safely you can write regex that captures all characters from the end of the start line pattern
        # to the pattern the starts the email
        
        ######################### TODO: write regex that captures the email, and the name #############################
        # email regex: this will capture the email exactly
        email_regex = r"(?<=\<).+(?=\>)|[A-Za-z0-9._%+-]+@[A-Za-z0-9._-]+(\.\w+)*" 
        # name regex: this will capture the name besides some characters before and after it that will be removed later
        name_regex = r"(?<=:\s).+(?=@)"
        ##############################################################################################################
        r_email = re.search(email_regex, recipient.group())
        r_name = re.search(name_regex, recipient.group())
    else:
        r_email = None
        r_name = None

    # We need to check as re.search() may return None
    if r_email is not None:
        recipient_email = r_email.group()
    else:
        recipient_email = None

    # We need to check as re.search() may return None
    if r_name is not None:
        # Since the name is not captured exactly, we need to substitute all unneeded characters
        
        ############################# TODO: write regex to capture characters to be removed #####################
        characters_remove_from_beginning = '^[^\w]+'
        characters_remove_from_end = '[^\w]+$'
        #########################################################################################################
        recipient_name = re.sub(characters_remove_from_end, "", re.sub(characters_remove_from_beginning, "", r_name.group()))
    else:
        recipient_name = None

    return recipient_email, recipient_name

# %%
# This function takes a full email and returns a string with the date

def getDate(email_item):
    ########################### TODO: write regex to match the whole line containing the date ########################
    line_date_regex = r"(?m)^Date:.+"
    ##################################################################################################################
    date_field = re.search(line_date_regex, email_item)

    if date_field is not None:
        #################################### TODO: write regex to match only the date ###############################
        # e.g. If the date is: Thu, 31 Oct 2002 22:17:55 +0100
        # you need to match only 31 Oct 2002
        date_only_regex = r"\d{1,2} \w{3} \d{4}"
        #############################################################################################################
        date = re.search(date_only_regex, date_field.group())
    else:
        date = None

    if date is not None:
        date_sent = date.group()
    else:
        date_sent = None

    return date_sent

# %%
# This function takes a full email item and returns a string with the email subject
def getSubject(email_item):
    ########################## TODO: write regex to match the whole line containing the subject #################
    line_subject_regex = r"(?m)^Subject:.+"
    #############################################################################################################
    subject_field = re.search(line_subject_regex, email_item)

    if subject_field is not None:
        #################### TODO: write regex with the pattern to be removed to capture the subject only ##########
        remove_pattern = r"Subject:"
        ############################################################################################################
        subject = re.sub(remove_pattern, "", subject_field.group())
    else:
        subject = None

    return subject

# %%
test = {}
print(contents[0])
test["sender_email"], test["sender_name"] = senderEmailAndName(contents[0])
test["recipient_email"], test["recipient_name"] = recipientEmailAndName(contents[0])
test["date_sent"] = getDate(contents[0])
test["subject"] = getSubject(contents[0])

print(test)
# Out:
#   Wed Oct 30 21:41:56 2002
# Return-Path: <james_ngola2002@maktoob.com>
# X-Sieve: cmu-sieve 2.0
# Return-Path: <james_ngola2002@maktoob.com>
# Message-Id: <200210310241.g9V2fNm6028281@cs.CU>
# From: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>
# Reply-To: james_ngola2002@maktoob.com
# To: webmaster@aclweb.org
# Date: Thu, 31 Oct 2002 02:38:20 +0000
# Subject: URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# X-Mailer: Microsoft Outlook Express 5.00.2919.6900 DM
# MIME-Version: 1.0
# Content-Type: text/plain; charset="us-ascii"
# Content-Transfer-Encoding: 8bit
# X-MIME-Autoconverted: from quoted-printable to 8bit by sideshowmel.si.UM id g9V2foW24311
# Status: O
#
# FROM:MR. JAMES NGOLA.
# CONFIDENTIAL TEL: 233-27-587908.
# E-MAIL: (james_ngola2002@maktoob.com).
#
# URGENT BUSINESS ASSISTANCE AND PARTNERSHIP.
#
#
# DEAR FRIEND,
#
# I AM ( DR.) JAMES NGOLA, THE PERSONAL ASSISTANCE TO THE LATE CONGOLESE (PRESIDENT LAURENT KABILA) WHO WAS ASSASSINATED BY HIS BODY GUARD ON 16TH JAN. 2001.
#
#
# THE INCIDENT OCCURRED IN OUR PRESENCE WHILE WE WERE HOLDING MEETING WITH HIS EXCELLENCY OVER THE FINANCIAL RETURNS FROM THE DIAMOND SALES IN THE AREAS CONTROLLED BY (D.R.C.) DEMOCRATIC REPUBLIC OF CONGO FORCES AND THEIR FOREIGN ALLIES ANGOLA AND ZIMBABWE, HAVING RECEIVED THE PREVIOUS DAY (USD$100M) ONE HUNDRED MILLION UNITED STATES DOLLARS, CASH IN THREE DIPLOMATIC BOXES ROUTED THROUGH ZIMBABWE.
#
# MY PURPOSE OF WRITING YOU THIS LETTER IS TO SOLICIT FOR YOUR ASSISTANCE AS TO BE A COVER TO THE FUND AND ALSO COLLABORATION IN MOVING THE SAID FUND INTO YOUR BANK ACCOUNT THE SUM OF (USD$25M) TWENTY FIVE MILLION UNITED STATES DOLLARS ONLY, WHICH I DEPOSITED WITH A SECURITY COMPANY IN GHANA, IN A DIPLOMATIC BOX AS GOLDS WORTH (USD$25M) TWENTY FIVE MILLION UNITED STATES DOLLARS ONLY FOR SAFE KEEPING IN A SECURITY VAULT FOR ANY FURTHER INVESTMENT PERHAPS IN YOUR COUNTRY.
#
# YOU WERE INTRODUCED TO ME BY A RELIABLE FRIEND OF MINE WHO IS A TRAVELLER,AND ALSO A MEMBER OF CHAMBER OF COMMERCE AS A RELIABLE AND TRUSTWORTHY PERSON WHOM I CAN RELY ON AS FOREIGN PARTNER, EVEN THOUGH THE NATURE OF THE TRANSACTION WAS NOT REVEALED TO HIM FOR SECURITY REASONS.
#
#
# THE (USD$25M) WAS PART OF A PROCEEDS FROM DIAMOND TRADE MEANT FOR THE LATE PRESIDENT LAURENT KABILA WHICH WAS DELIVERED THROUGH ZIMBABWE IN DIPLOMATIC BOXES. THE BOXES WERE KEPT UNDER MY CUSTODY BEFORE THE SAD EVENT THAT TOOK THE LIFE OF (MR. PRESIDENT).THE CONFUSION THAT ENSUED AFTER THE ASSASSINATION AND THE SPORADIC SHOOTING AMONG THE FACTIONS, I HAVE TO RUN AWAY FROM THE COUNTRY FOR MY DEAR LIFE AS I AM NOT A SOLDIER BUT A CIVIL SERVANT I CROSSED RIVER CONGO TO OTHER SIDE OF CONGO LIBREVILLE FROM THERE I MOVED TO THE THIRD COUNTRY GHANA WHERE I AM PRESENTLY TAKING REFUGE.
#
# AS A MATTER OF FACT, WHAT I URGENTLY NEEDED FROM YOU IS YOUR ASSISTANCE IN MOVING THIS MONEY INTO YOUR ACCOUNT IN YOUR COUNTRY FOR INVESTMENT WITHOUT RAISING EYEBROW. FOR YOUR ASSISTANCE I WILL GIVE YOU 20% OF THE TOTAL SUM AS YOUR OWN SHARE WHEN THE MONEY GETS TO YOUR ACCOUNT, WHILE 75% WILL BE FOR ME, OF WHICH WITH YOUR KIND ADVICE I HOPE TO INVEST IN PROFITABLE VENTURE IN YOUR COUNTRY IN OTHER TO SETTLE DOWN FOR MEANINGFUL LIFE, AS I AM TIRED OF LIVING IN A WAR ENVIRONMENT.
#
# THE REMAINING 5% WILL BE USED TO OFFSET ANY COST INCURRED IN THE CAUSE OF MOVING THE MONEY TO YOUR ACCOUNT. IF THE PROPOSAL IS ACCEPTABLE TO YOU PLEASE CONTACT ME IMMEDIATELY THROUGH THE ABOVE TELEPHONE AND E-MAIL, TO ENABLE ME ARRANGE FACE TO FACE MEETING WITH YOU IN GHANA FOR THE CLEARANCE OF THE FUNDS BEFORE TRANSFRING IT TO YOUR BANK ACCOUNT AS SEEING IS BELIEVING.
#
# FINALLY, IT IS IMPORTANT ALSO THAT I LET YOU UNDERSTAND THAT THERE IS NO RISK INVOLVED WHATSOEVER AS THE MONEY HAD NO RECORD IN KINSHASA FOR IT WAS MEANT FOR THE PERSONAL USE OF (MR. PRESIDEND ) BEFORE THE NEFARIOUS INCIDENT OCCURRED, AND ALSO I HAVE ALL THE NECESSARY DOCUMENTS AS REGARDS TO THE FUNDS INCLUDING THE (CERTIFICATE OF DEPOSIT), AS I AM THE DEPOSITOR OF THE CONSIGNMENT.
#
#
# LOOKING FORWARD TO YOUR URGENT RESPONSE.
#
# YOUR SINCERELY,
#
# MR. JAMES NGOLA.
#
#
#
#
#
#
#
#
#
#
#
# <re.Match object; span=(184, 238), match='From: "MR. JAMES NGOLA." <james_ngola2002@maktoob>
# {'sender_email': 'james_ngola2002@maktoob.com', 'sender_name': 'MR. JAMES NGOLA', 'recipient_email': 'webmaster@aclweb.org', 'recipient_name': 'webmaster', 'date_sent': '31 Oct 2002', 'subject': ' URGENT BUSINESS ASSISTANCE AND PARTNERSHIP'}

# %%
# Let's construct our emails
emails = []
for email_item in contents:
    emails_dict = {}
    emails_dict["sender_email"], emails_dict["sender_name"] = senderEmailAndName(email_item)
    emails_dict["recipient_email"], emails_dict["recipient_name"] = recipientEmailAndName(email_item)
    emails_dict["date_sent"] = getDate(email_item)
    emails_dict["subject"] = getSubject(email_item)
    
    emails.append(emails_dict)
    
assert len(emails) == 3976, "You have something wrong"
# Out:
# <re.Match object; span=(184, 238), match='From: "MR. JAMES NGOLA." <james_ngola2002@maktoob>
# <re.Match object; span=(198, 252), match='From: "Mr. Ben Suleman" <bensul2004nng@spinfinder>
# <re.Match object; span=(180, 229), match='From: "PRINCE OBONG ELEME" <obong_715@epatra.com>>
# <re.Match object; span=(180, 229), match='From: "PRINCE OBONG ELEME" <obong_715@epatra.com>>
# <re.Match object; span=(181, 223), match='From: "Maryam Abacha" <m_abacha03@www.com>'>
# <re.Match object; span=(172, 213), match='From: Kuta David <davidkuta@postmark.net>'>
# <re.Match object; span=(132, 187), match='From: "Barrister tunde dosumu" <tunde_dosumu@lyco>
# <re.Match object; span=(188, 242), match='From: "William Drallo" <william2244drallo@maktoob>
# <re.Match object; span=(193, 242), match='From: "MR USMAN ABDUL" <abdul_817@rediffmail.com>>
# <re.Match object; span=(132, 178), match='From: "Tunde  Dosumu" <barrister_td@lycos.com>'>
# <re.Match object; span=(193, 244), match='From: MR TEMI JOHNSON <temijohnson2@rediffmail.co>
# <re.Match object; span=(184, 229), match='From: "Dr.Sam jordan" <sjordan@diplomats.com>'>
# <re.Match object; span=(178, 203), match='From: p_brown2@lawyer.com'>
# <re.Match object; span=(172, 193), match='From: mic_k1@post.com'>
# <re.Match object; span=(189, 244), match='From: "COL. MICHAEL BUNDU" <mikebunduu1@rediffmai>
# <re.Match object; span=(168, 215), match='From: "MRS MARIAM ABACHA" <elixwilliam@usa.com>'>
# <re.Match object; span=(182, 230), match='From: " DR. ANAYO AWKA " <anayoawka@hotmail.com>'>
# <re.Match object; span=(182, 230), match='From: " DR. ANAYO AWKA " <anayoawka@hotmail.com>'>
# <re.Match object; span=(308, 354), match='From: "Victor Aloma" <victorloma@netscape.net>'>
# <re.Match object; span=(268, 314), match='From: "Victor Aloma" <victorloma@netscape.net>'>
# <re.Match object; span=(234, 283), match='From: "JAMES NGOLA" <james_ngola2002@maktoob.com>>
# <re.Match object; span=(228, 270), match='From: "MARTIN CHIME" <martinchime@usa.com>'>
# <re.Match object; span=(336, 380), match='From: "Mr George Mboro" <mboro1555@post.com>'>
# <re.Match object; span=(336, 381), match='From: "MARTIN  CHIME" <martinchime@borad.com>'>
# <re.Match object; span=(297, 342), match='From: "MARTIN  CHIME" <martinchime@borad.com>'>
# <re.Match object; span=(246, 279), match='From: <edema_mb@phantomemail.com>'>
# <re.Match object; span=(239, 272), match='From: <edema_mb@phantomemail.com>'>
# <re.Match object; span=(197, 246), match='From: "ADE WILLIAMS" <adewilliams_ade@lawyer.com>>
# <re.Match object; span=(181, 205), match='From: smithkam2@post.com'>
# <re.Match object; span=(272, 316), match='From: "MRS. M SESE-SEKO" <sesm@omaninfo.com>'>
# <re.Match object; span=(449, 488), match='From: "obina okoro" <obinaokoro@37.com>'>
# <re.Match object; span=(385, 436), match='From: "DR. JAMES  ALBERT" <jamesalbert0@eircom.ne>
# <re.Match object; span=(158, 230), match='From: adamuohiroma adamuohiroma <adamuohiroma.ada>
# <re.Match object; span=(286, 330), match='From: "MR FRED OBI." <fredobi3@omaninfo.com>'>
# <re.Match object; span=(441, 478), match='From: "mbeki ngumeni" <mbengu@37.com>'>
# <re.Match object; span=(171, 213), match='From: mahoyi mamudu <mmahoyi@caramail.com>'>
# <re.Match object; span=(217, 255), match='From: "Mr. David Agu" <adgua@mail.com>'>
# <re.Match object; span=(175, 225), match='From: "bell.idr bell.idr" <bbell.idr@caramail.com>
# <re.Match object; span=(181, 240), match='From: "idris.bello idris.bello" <iidris.bello@car>
# <re.Match object; span=(256, 282), match='From: john2002@bluemail.ch'>
# <re.Match object; span=(195, 244), match='From: "CLEMENT APUTE" <clem-apute@consultant.com>>
# <re.Match object; span=(201, 254), match='From: "MR GODWIN IGBUNU" <g.godwin12345@caramail.>
# <re.Match object; span=(175, 225), match='From: "bell.idr bell.idr" <bbell.idr@caramail.com>
# <re.Match object; span=(217, 255), match='From: "Mr. David Agu" <dav84@mail.com>'>
# <re.Match object; span=(443, 484), match='From: "deborah kabila" <kabila72b@37.com>'>
# <re.Match object; span=(304, 337), match='From: Khalifa Sese <kss07@go.com>'>
# <re.Match object; span=(304, 337), match='From: Khalifa Sese <kss07@go.com>'>
# <re.Match object; span=(242, 300), match='From: "MOHAMMED BELLO (Ph.D)" <mohammed_bello_1@y>
# <re.Match object; span=(202, 257), match='From: "PETER WILLIAMS" <cooooofoooooooo@rediffmai>
# <re.Match object; span=(171, 218), match='From: "Oliveira Savimbi" <olivsav@netscape.net>'>
# <re.Match object; span=(171, 219), match='From: "Mr. Daniel Osondu" <tdannosondu@mail.com>'>
# <re.Match object; span=(75, 115), match='From: <williamsdaniel1@phantomemail.com>'>
# <re.Match object; span=(147, 179), match='From: "Ruka" <rulagg@excite.com>'>
# <re.Match object; span=(235, 277), match='From: "IDRIS ADAMU" <idris2003942@aol.com>'>
# <re.Match object; span=(161, 208), match='From: "DR.  SANNI  SABO" <davidmensoh@mail.com>'>
# <re.Match object; span=(161, 208), match='From: "DR.  SANNI  SABO" <davidmensoh@mail.com>'>
# <re.Match object; span=(162, 210), match='From: "Ibrahim Galadima" <ig_esq@rediffmail.com>'>
# <re.Match object; span=(196, 227), match='From: ademola1950@hknetmail.com'>
# <re.Match object; span=(132, 180), match='From: "Mohammed Abacha" <a_mabachas@yahoo.co.uk>'>
# <re.Match object; span=(133, 192), match='From: "PRINCE TUNDE O ADISARAKI" <princeadisaraki>
# <re.Match object; span=(118, 165), match='From: "judeestrada" <judeestrada2@dmailman.com>'>
# <re.Match object; span=(171, 219), match='From: "JONATHAN  MOKOENA" <davidmensoh@mail.com>'>
# <re.Match object; span=(360, 384), match='From: olu@mailservice.ms'>
# <re.Match object; span=(194, 235), match='From: "res bob12" <resbobi2@al-islam.com>'>
# <re.Match object; span=(180, 239), match='From: "LADY MARYAM ABACHA " <mariam.abacha58@bore>
# <re.Match object; span=(128, 181), match='From: "MR.TUNDE  BALOGUN" <tundebalogun@omaninfo.>
# <re.Match object; span=(130, 184), match='From: "MR.BENSON  ATTAH" <mrbenson_attah@omaninfo>
# <re.Match object; span=(178, 232), match='From: "MR.BENSON  ATTAH" <mrbenson_attah@omaninfo>
# <re.Match object; span=(176, 229), match='From: "MR.TUNDE  BALOGUN" <tundebalogun@omaninfo.>
# <re.Match object; span=(133, 192), match='From: "LADY MARYAM ABACHA " <mariam.abacha57@bore>
# <re.Match object; span=(171, 218), match='From: "DR.  SANNI  SABO" <davidmensoh@mail.com>'>
# <re.Match object; span=(189, 263), match='From: "Dr Luisa Pimental Estrada" <luisaestrada20>
# <re.Match object; span=(70, 122), match='From: "Graham Douglas" <douglas.graham@caramail.c>
# <re.Match object; span=(112, 149), match='From: luis oboh <oluis2@caramail.com>'>
# <re.Match object; span=(112, 149), match='From: luis oboh <oluis2@caramail.com>'>
# <re.Match object; span=(304, 355), match='From: "savimbidenis@www.com" <savimbidenis@www.co>
# <re.Match object; span=(166, 223), match='From: "Nsekou Mobutu Sesekou" <sekou_family@mails>
# <re.Match object; span=(178, 230), match='From: "DR. BELLO MUSA" <dr_bellomusa01@omaninfo.c>
# <re.Match object; span=(146, 197), match='From: Frank Williams <frankwilliams2@starmedia.co>
# <re.Match object; span=(353, 418), match='From: "=?iso-8859-1?Q?lawrence.smith?=" <lawrence>
# <re.Match object; span=(129, 176), match='From: "DONALD  ATTAH" <donaldattah@netzero.com>'>
# <re.Match object; span=(341, 384), match='From: "daniel innocent" <daninno555@37.com>'>
# <re.Match object; span=(481, 522), match='From: "deborah kabila" <kabila72i@37.com>'>
# <re.Match object; span=(183, 231), match='From: "peter" <peter_savimbi20@phantomemail.com>'>
# <re.Match object; span=(400, 449), match='From: "joseph benson" <josephbenson@weedmail.com>>
# <re.Match object; span=(252, 277), match='From: mr_bb@hknetmail.com'>
# <re.Match object; span=(341, 379), match='From: "pat odogu" <pat11@weedmail.com>'>
# <re.Match object; span=(167, 213), match='From: felix lamine <felix.lamine@caramail.com>'>
# <re.Match object; span=(131, 187), match='From: "PATRICK  MOHAMMED" <patrickmohammed@omanin>
# <re.Match object; span=(178, 234), match='From: "PATRICK  MOHAMMED" <patrickmohammed@omanin>
# <re.Match object; span=(132, 186), match='From: "Mr. Lawrence Abba" <lawrenceabba@operamail>
# <re.Match object; span=(151, 180), match='From: bill_james4@bluemail.ch'>
# <re.Match object; span=(347, 378), match='From: Mr Benard Gelicah Sankoh.'>
# <re.Match object; span=(62, 103), match='From: "MALCOM TUTU" <macontu05@yahoo.com>'>
# <re.Match object; span=(123, 164), match='From: "MALCOM TUTU" <macontu05@yahoo.com>'>
# <re.Match object; span=(71, 123), match='From: stevens bangura <stevens.bangura@caramail.c>
# <re.Match object; span=(174, 225), match='From: "MR. DONALD ATTAH" <donaldattah@omaninfo.co>
# <re.Match object; span=(172, 221), match='From: "Dr mariam abacha" <marabac011@hotmail.com>>
# <re.Match object; span=(251, 297), match='From: Frank Ikpendu <frankikpendu3@mail.co.za>'>
# <re.Match object; span=(138, 190), match='From: "jeffery hill" <jeffery_hill10007@hotmail.c>
# <re.Match object; span=(123, 165), match='From: "malcom tutu" <macontu028@yahoo.com>'>
# <re.Match object; span=(129, 171), match='From: "malcom tutu" <macontu028@yahoo.com>'>
# <re.Match object; span=(339, 375), match='From: "sam aluko" <samaluko1@37.com>'>
# <re.Match object; span=(176, 226), match='From: "GEORGE  KABILA" <ggeorgekabyl@caramail.com>
# <re.Match object; span=(172, 219), match='From: "CYRIL AKWARANDU" <madu_invest@yahoo.com>'>
# <re.Match object; span=(172, 219), match='From: "CYRIL AKWARANDU" <madu_invest@yahoo.com>'>
# <re.Match object; span=(159, 202), match='From: "MR.YARO BAMIYI" <doomer@themail.com>'>
# <re.Match object; span=(115, 157), match='From: "barr.femi" <barr.femi@caramail.com>'>
# <re.Match object; span=(171, 220), match='From: "DR DOUGLAS NWANKWO" <douglankwo@yahoo.com>>
# <re.Match object; span=(128, 186), match='From: "Mrs. Safi  Al Mustapha" <leathercity1@iran>
# <re.Match object; span=(131, 189), match='From: "Mrs. Safi  Al Mustapha" <leathercity1@iran>
# <re.Match object; span=(174, 224), match='From: "Dr Mariam abacha" <mariam.aba@caramail.com>
# <re.Match object; span=(168, 214), match='From: "Dr.Moses" <moses1970@englishexpert.com>'>
# <re.Match object; span=(136, 182), match='From: "Dr.Moses" <moses1970@englishexpert.com>'>
# <re.Match object; span=(126, 178), match='From: "DR. OLUSEGUN SMITH" <olu002@phantomemail.c>
# <re.Match object; span=(132, 189), match='From: "Dr. Bernard Makelele" <benkelele@phantomem>
# <re.Match object; span=(197, 231), match='From: chiedo_jonathan2@netzero.com'>
# <re.Match object; span=(168, 210), match='From: "kaseke kenneth" <kasekek@email.com>'>
# <re.Match object; span=(242, 272), match='From: willbanigo003@juntos.com'>
# <re.Match object; span=(140, 196), match='From: "DR ABDULL RASAQ" <drabdullrasaq@phantomema>
# <re.Match object; span=(136, 192), match='From: "DR ABDULL RASAQ" <drabdullrasaq@phantomema>
# <re.Match object; span=(160, 202), match='From: "williame ume" <kkalume@bluemail.ch>'>
# <re.Match object; span=(225, 251), match='From: jisrael2@breathe.com'>
# <re.Match object; span=(120, 161), match='From: "KENNETH ILOKA" <umarb@themail.com>'>
# <re.Match object; span=(208, 237), match='From: charlesnwodo@excite.com'>
# <re.Match object; span=(125, 172), match='From: "Oliveira Savimbi" <olivsav@netscape.net>'>
# <re.Match object; span=(236, 282), match='From: "James DeSouza." <jdsouza1@hotvoice.com>'>
# <re.Match object; span=(242, 288), match='From: "James DeSouza." <jdsouza1@hotvoice.com>'>
# <re.Match object; span=(64, 110), match='From: "James DeSouza." <jdsouza1@hotvoice.com>'>
# <re.Match object; span=(124, 170), match='From: "James DeSouza." <jdsouza1@hotvoice.com>'>
# <re.Match object; span=(329, 353), match='From: chinaeke7@juno.com'>
# <re.Match object; span=(273, 314), match='From: "PAPA BELLO" <papabello@lawyer.com>'>
# <re.Match object; span=(238, 295), match='From: "Dr. Don Arturo Ramitez." <don_1000@fasterm>
# <re.Match object; span=(288, 334), match='From: "E E" <foryourconsumption_2@hotmail.com>'>
# <re.Match object; span=(233, 268), match='From: "KABILA" <greenkab@email.com>'>
# <re.Match object; span=(236, 283), match='From: "Oliveira Savimbi" <olivsav@netscape.net>'>
# <re.Match object; span=(243, 295), match='From: "MR DANIEL KALU" <danielkalukalu@netscape.n>
# <re.Match object; span=(300, 337), match='From: SOLOMON azeez <sameezx6@go.com>'>
# <re.Match object; span=(300, 337), match='From: SOLOMON azeez <sameezx6@go.com>'>
# <re.Match object; span=(296, 333), match='From: SOLOMON azeez <sameezx6@go.com>'>
# <re.Match object; span=(296, 333), match='From: SOLOMON azeez <sameezx6@go.com>'>
# <re.Match object; span=(296, 333), match='From: SOLOMON azeez <sameezx6@go.com>'>
# <re.Match object; span=(228, 261), match='From: "NOSA" <ni452003@yahoo.com>'>
# <re.Match object; span=(188, 223), match='From: "MR TUNDA" <tundatx@zapo.net>'>
# <re.Match object; span=(231, 280), match='From: "DR STEPHEN UMAH" <u.stephen1@caramail.com>>
# <re.Match object; span=(124, 172), match='From: "Dr stephen umah" <u.stephen@caramail.com>'>
# <re.Match object; span=(174, 215), match='From: "JOHN CHOMA" <jochom12@hotmail.com>'>
# <re.Match object; span=(115, 155), match='From: "DR TONY COLE" <tony3@ecplaza.net>'>
# <re.Match object; span=(115, 155), match='From: "DR TONY COLE" <tony3@ecplaza.net>'>
# <re.Match object; span=(123, 170), match='From: "DR. GOODWILL MPENZA" <savim_5@email.com>'>
# <re.Match object; span=(221, 246), match='From: wbanigo@anfmail.com'>
# <re.Match object; span=(121, 167), match='From: "Engr. William Goye" <wgoye@ecplaza.net>'>
# <re.Match object; span=(220, 268), match='From: "FRANK  GUEI JNR." <frank_jnr3@myself.com>'>
# <re.Match object; span=(181, 212), match='From: solochuks5000@breathe.com'>
# <re.Match object; span=(92, 136), match='From: Farouk Al-Bashar <falbashar@olumo.net>'>
# <re.Match object; span=(120, 165), match='From: "WILLIAM   OKAFOR" <fowika@ecplaza.net>'>
# <re.Match object; span=(97, 141), match='From: Farouk Al-Bashar <falbashar@olumo.net>'>
# <re.Match object; span=(128, 176), match='From: "DR STEPHEN AKIGA" <ohunola@latinmail.com>'>
# <re.Match object; span=(127, 175), match='From: "DR STEPHEN AKIGA" <ohunola@latinmail.com>'>
# <re.Match object; span=(126, 167), match='From: "Ola Kelvin" <olakelv3@ecplaza.net>'>
# <re.Match object; span=(559, 613), match='From: MRS CECILIA MARK AKU <mrscecilliaak@ecplaza>
# <re.Match object; span=(556, 600), match='From: "MR.DON UBALA," <donubala@ecplaza.net>'>
# <re.Match object; span=(190, 234), match='From: "Dr. Wilson" <itwilson33@netscape.net>'>
# <re.Match object; span=(344, 364), match='From: James Kabila. '>
# <re.Match object; span=(61, 85), match='From: dayonaps04@aol.com'>
# <re.Match object; span=(173, 219), match='From: "Oliveira Savimbi" <olisav@netscape.net>'>
# <re.Match object; span=(194, 241), match='From: "Dr Pascal Ugoti" <pascal_962@myself.com>'>
# <re.Match object; span=(194, 241), match='From: "Dr Pascal Ugoti" <pascal_962@myself.com>'>
# <re.Match object; span=(134, 192), match='From: "Professor Frank Obi" <professorfranko@nets>
# <re.Match object; span=(127, 167), match='From: "koffi joseph" <offjo@hotmail.com>'>
# <re.Match object; span=(192, 247), match='From: "ENGR: KUMALO DILIZA" <kumalodiliza6@ecplaz>
# <re.Match object; span=(124, 174), match='From: "MR GBENRO ADEGBOLA" <salisu_bola@yahoo.com>
# <re.Match object; span=(189, 232), match='From: "MAKO OKERE" <okere1972@netscape.net>'>
# <re.Match object; span=(60, 100), match='From: "GBENGA ALUKO" <gbealuko@voila.fr>'>
# <re.Match object; span=(129, 177), match='From: "MR, DOMAS K, YANK" <kecityy@netscape.net>'>
# <re.Match object; span=(107, 153), match='From: "Oliveira Savimbi" <olisav@netscape.net>'>
# <re.Match object; span=(127, 173), match='From: "DR. PAUL BABS." <paulbabs@caramail.com>'>
# <re.Match object; span=(122, 170), match='From: "grace abba-gana" <gabbagana@albawaba.com>'>
# <re.Match object; span=(204, 258), match='From: "salatu_ibru300" <salatu_ibru300@indiatimes>
# <re.Match object; span=(131, 184), match='From: "ADEROJU MUYIWA" <ademuyiwa1950@rediffmail.>
# <re.Match object; span=(126, 175), match='From: "Mr Olu Martins" <olu_martins007@yahoo.com>>
# <re.Match object; span=(128, 177), match='From: "maryam  abacha" <maryamy2k@indiatimes.com>>
# <re.Match object; span=(130, 183), match='From: "MRS ROSE SAVIMBI" <rosesavibmi@rediffmail.>
# <re.Match object; span=(228, 263), match='From: luisaastrada@portugalmail.com'>
# <re.Match object; span=(137, 186), match='From: MARIAM ABACHA <mariamabacha202@ecplaza.net>>
# <re.Match object; span=(190, 236), match='From: "Bola  Harry" <bolaharryt@tiscali.co.uk>'>
# <re.Match object; span=(130, 176), match='From: "Bola  Harry" <bolaharryt@tiscali.co.uk>'>
# <re.Match object; span=(122, 165), match='From: "DR.TUNJI OWO" <tunjiowo@regards.net>'>
# <re.Match object; span=(185, 224), match='From: Owen Mubane <muowen^%&@mmail.com>'>
# <re.Match object; span=(186, 229), match='From: "DR.TUNJI OWO" <tunjiowo@regards.net>'>
# <re.Match object; span=(275, 319), match='From: Mohammed Abacha <orionventures@go.com>'>
# <re.Match object; span=(182, 237), match='From: "ENGR ZULUMAKALENI." <zulumakaleni1@netscap>
# <re.Match object; span=(123, 176), match='From: "DR (MRS) MARIAM ABACHA" <koolizzy@hotmail.>
# <re.Match object; span=(132, 178), match='From: "MR. TAMBO" <engranthony_zuma@lycos.com>'>
# <re.Match object; span=(183, 230), match='From: Dukat Kabila <dukatka_s22@rediffmail.com>'>
# <re.Match object; span=(179, 231), match='From: "Dr. Bouguiba Samuel" <samaguiba1@ecplaza.n>
# <re.Match object; span=(193, 230), match='From: James Oni <jamesoni2000@go.com>'>
# <re.Match object; span=(193, 230), match='From: James Oni <jamesoni2000@go.com>'>
# <re.Match object; span=(193, 230), match='From: James Oni <jamesoni2000@go.com>'>
# <re.Match object; span=(191, 231), match='From: CARLOS SAVIMBI <carlos_sav@go.com>'>
# <re.Match object; span=(127, 181), match='From: "MRS, AMINA BOLA IGE" <isa_kaitha2002@yahoo>
# <re.Match object; span=(131, 181), match='From: "Andy Bello" <andy_bello2003@rediffmail.com>
# <re.Match object; span=(72, 122), match='From: "Andy Bello" <andy_bello2003@rediffmail.com>
# <re.Match object; span=(90, 142), match='From: "AHMED MARTINS. D" <martinsdanjuma@mail15.c>
# <re.Match object; span=(334, 380), match='From: Gabriel Kali <gadikali@gatechambers.com>'>
# <re.Match object; span=(192, 243), match='From: "Mr.Kola Awosika" <kola.awosika@caramail.co>
# <re.Match object; span=(135, 182), match='From: "SAAD A.ALLI" <husseinalli33@zwallet.com>'>
# <re.Match object; span=(191, 239), match='From: "JOHNSON ABBAS" <johnsonabbas@zwallet.com>'>
# <re.Match object; span=(219, 266), match='From: "Dr.Tito Sithole." <macusgee@hotmail.com>'>
# <re.Match object; span=(178, 220), match='From: KATURA BANGA <mrkatban@netscape.net>'>
# <re.Match object; span=(130, 177), match='From: "MADAM MARYAM" <maryamy2k@indiatimes.com>'>
# <re.Match object; span=(129, 178), match='From: "DELE MARTINS" <delemartins@indiatimes.com>>
# <re.Match object; span=(228, 270), match='From: saidi fatou <saidifatou@moldova.com>'>
# <re.Match object; span=(219, 276), match='From: "Mrs. Mariam M. Sese-seko" <Liusa11@totalis>
# <re.Match object; span=(128, 176), match='From: "MICHAEL AFOLABI" <frankemeni@ecplaza.net>'>
# <re.Match object; span=(72, 123), match='From: NZANGA MOBUTU <Nzangamobutu@phantomemail.co>
# <re.Match object; span=(135, 186), match='From: NZANGA MOBUTU <Nzangamobutu@phantomemail.co>
# <re.Match object; span=(133, 184), match='From: "CHUKS ANTHONY" <chuksanthony05@netscape.ne>
# <re.Match object; span=(125, 174), match='From: "godfrey eche3" <godfreyeche3@albawaba.com>>
# <re.Match object; span=(125, 174), match='From: "godfrey eche3" <godfreyeche3@albawaba.com>>
# <re.Match object; span=(128, 190), match='From: "Muhammad Khalil Hasan" <khalil_muhammad@my>
# <re.Match object; span=(172, 234), match='From: "Muhammad Khalil Hasan" <khalil_muhammad@my>
# <re.Match object; span=(199, 257), match='From: "Hamzat Sulaiman" <hamzatsulaiman@unionintb>
# <re.Match object; span=(188, 229), match='From: "keven wei" <envoltbattery@163.com>'>
# <re.Match object; span=(253, 279), match='From: ami44000@netzero.com'>
# <re.Match object; span=(129, 183), match='From: "Mr Chuks Anthony" <chuksanthony05@netscape>
# <re.Match object; span=(173, 220), match='From: " JOHNSON ELENDU " <jelendu@nzoomail.com>'>
# <re.Match object; span=(244, 293), match='From: "Mike Jide" <mijez2001_nnpc@indiatimes.com>>
# <re.Match object; span=(136, 185), match='From: "Mike Jide" <mijez2001_nnpc@indiatimes.com>>
# <re.Match object; span=(291, 318), match='From: wale_williams@post.cz'>
# <re.Match object; span=(290, 331), match='From: "Fred Mbonu" <mfrred@hknetmail.com>'>
# <re.Match object; span=(296, 337), match='From: "Fred Mbonu" <mfrred@hknetmail.com>'>
# <re.Match object; span=(134, 183), match='From: JOHN COLEMEN <johncolemen1970@netscape.net>>
# <re.Match object; span=(196, 227), match='From: j_remitance@hknetmail.com'>
# <re.Match object; span=(231, 290), match='From: "Mrs. Mariam M. Sese-seko" <liusaxxxx@total>
# <re.Match object; span=(226, 263), match='From: "MakamSomo" <sa_03@breathe.com>'>
# <re.Match object; span=(230, 281), match='From: "Engr. Musa  Akim." <engr_musa@hknetmail.co>
# <re.Match object; span=(126, 177), match='From: "Engr. Musa  Akim." <engr_musa@hknetmail.co>
# <re.Match object; span=(295, 344), match='From: "DR.MATTHEW OKOYE" <mattokoye@didamail.com>>
# <re.Match object; span=(280, 322), match='From: "abram nkomo" <ab_nkomo@hotmail.com>'>
# <re.Match object; span=(188, 224), match='From: maira ssesko <sseko019@go.com>'>
# <re.Match object; span=(67, 123), match='From: Joseph Mobutu Sese-Seko <jmobutu189@latinma>
# <re.Match object; span=(179, 225), match='From: "Mariam Abacha" <myriaj03@femail.com.au>'>
# <re.Match object; span=(67, 123), match='From: Joseph Mobutu Sese-Seko <jmobutu189@latinma>
# <re.Match object; span=(128, 179), match='From: "PRINCE FOLU FADAKA" <folufadaka@netzero.co>
# <re.Match object; span=(63, 102), match='From: sussy emma <e.sussy@caramail.com>'>
# <re.Match object; span=(183, 223), match='From: "Harry O Harry" <harry1@hknet.com>'>
# <re.Match object; span=(117, 159), match='From: Drmoore James <jdrmoore@personal.ro>'>
# <re.Match object; span=(191, 251), match='From: "PRINCE WILLIAMS" <princewilliamson99@portu>
# <re.Match object; span=(201, 264), match='From: "PRINCE M  WILLIAMS" <princewilliamson99@po>
# <re.Match object; span=(189, 238), match='From: "MRS CECILIA  AKU" <aku_cmrs2002@surfy.net>>
# <re.Match object; span=(129, 174), match='From: MECK MAHABILE <mahabile10@netscape.net>'>
# <re.Match object; span=(128, 172), match='From: "FRANK BELLO" <fbellojr39@hotmail.com>'>
# <re.Match object; span=(130, 174), match='From: "FRANK BELLO" <fbellojr39@hotmail.com>'>
# <re.Match object; span=(130, 180), match='From: "Mr. Mike Obodoh" <mike.obodoh@caramail.com>
# <re.Match object; span=(129, 188), match='From: "Barrister. Bassey  Owo" <basseyowo300@hkne>
# <re.Match object; span=(122, 161), match='From: "MUYIWA IGE" <bechmank@yahoo.com>'>
# <re.Match object; span=(122, 165), match='From: "Dr.Tunde Cole" <tundecole@uboot.com>'>
# <re.Match object; span=(121, 164), match='From: "Dr Tunde Cole" <tundecole@uboot.com>'>
# <re.Match object; span=(119, 157), match='From: "williamume" <willyume@zapo.net>'>
# <re.Match object; span=(187, 233), match='From: "Mr.Philip Jones" <philjones1@uboot.com>'>
# <re.Match object; span=(130, 160), match='From: solosavimbi@netscape.com'>
# <re.Match object; span=(127, 172), match='From: "LEO  WILLIAMS" <leowilliams3@ipost.cz>'>
# <re.Match object; span=(314, 364), match='From: =?iso-8859-1?Q?makathy?= <makathy@libero.it>
# <re.Match object; span=(128, 176), match='From: "MRS MARY SANKOH" <sank_mary6@popmail.com>'>
# <re.Match object; span=(121, 163), match='From: "Mr.Bom Uche" <mrbom@fastermail.com>'>
# <re.Match object; span=(123, 165), match='From: "Mr.Bom Uche" <mrbom@fastermail.com>'>
# <re.Match object; span=(299, 351), match='From: ikhayere obinyan <ikhayere6000@addlebrain.c>
# <re.Match object; span=(124, 174), match='From: "Mr. Daniel Abass." <danielabass@afmail.com>
# <re.Match object; span=(121, 161), match='From: BASHER MOBUTU <basher39@lycos.com>'>
# <re.Match object; span=(241, 284), match='From: evans peter <evanspeter@hkonline.com>'>
# <re.Match object; span=(126, 179), match='From: "CHIEF(DR.)BODE GEORGE" <bode_george@xuppa.>
# <re.Match object; span=(127, 180), match='From: "CHIEF(DR.)BODE GEORGE" <bode_george@xuppa.>
# <re.Match object; span=(190, 240), match='From: "GREGORY PREMIER" <gregoryprem@incamail.com>
# <re.Match object; span=(191, 232), match='From: "....." <xxxxnnnnaaaa@netscape.net>'>
# <re.Match object; span=(127, 170), match='From: "Mr.Fred Obi" <fredobi02@zwallet.com>'>
# <re.Match object; span=(212, 249), match='From: idris umar <idrisumar94@go.com>'>
# <re.Match object; span=(387, 424), match='From: idris umar <idrisumar94@go.com>'>
# <re.Match object; span=(322, 359), match='From: idris umar <idrisumar94@go.com>'>
# <re.Match object; span=(286, 331), match='From: "daniel bello" <danbello07@hotmail.com>'>
# <re.Match object; span=(293, 336), match='From: "Mohammed Abacha" <dansekou@voila.fr>'>
# <re.Match object; span=(295, 338), match='From: "Mohammed Abacha" <dansekou@voila.fr>'>
# <re.Match object; span=(295, 334), match='From: "mrs m mbeki" <mrsmbeki@juno.com>'>
# <re.Match object; span=(120, 164), match='From: "Kola Daniel" <kolad05@indiatimes.com>'>
# <re.Match object; span=(108, 170), match='From: E-Loan Consumer Department <consumer.suppor>
# <re.Match object; span=(152, 214), match='From: E-Loan Consumer Department <consumer.suppor>
# <re.Match object; span=(108, 170), match='From: E-Loan Consumer Department <consumer.suppor>
# <re.Match object; span=(248, 276), match='From: princeige@mail3000.com'>
# <re.Match object; span=(133, 191), match='From: "Francis Sonto Mbomam" <dr_francis_mboma0@l>
# <re.Match object; span=(111, 172), match='From: Wells Fargo Accounting <wfba.accounting@wel>
# <re.Match object; span=(111, 172), match='From: Wells Fargo Accounting <wfba.accounting@wel>
# <re.Match object; span=(111, 172), match='From: Wells Fargo Accounting <wfba.accounting@wel>
# <re.Match object; span=(76, 117), match='From: frank <frankzambani42@netscape.net>'>
# <re.Match object; span=(71, 91), match='From: "Pandindra" <>'>
# <re.Match object; span=(27, 75), match='From: usman aminu <dr_aminuusman@anytimenow.com>'>
# <re.Match object; span=(132, 181), match='From: "Dr .Titi okonkwo" <titi_okonkwo@yahoo.com>>
# <re.Match object; span=(128, 178), match='From: "Dr .Titiokonkwo" <titiokonkwo234@yahoo.com>
# <re.Match object; span=(63, 121), match='From: "Godwin Ekpontu Sangana, Esq" <ejieego@nets>
# <re.Match object; span=(76, 134), match='From: "Godwin Ekpontu Sangana, Esq" <ejieego@nets>
# <re.Match object; span=(63, 121), match='From: "Godwin Ekpontu Sangana, Esq" <ejieego@nets>
# <re.Match object; span=(76, 134), match='From: "Godwin Ekpontu Sangana, Esq" <ejieego@nets>
# <re.Match object; span=(121, 165), match='From: ENGR MARK DAVID <igho200@netscape.net>'>
# <re.Match object; span=(221, 266), match='From: "Fadaka Randebe" <randebe@kalpoint.com>'>
# <re.Match object; span=(121, 166), match='From: "Fadaka Randebe" <randebe@kalpoint.com>'>
# <re.Match object; span=(264, 305), match='From: Ali Mohammed <ali_mohammed@123.com>'>
# <re.Match object; span=(124, 196), match='From: "First Bank Nig. Plc.( Dr. Femi Johnson.)" >
# <re.Match object; span=(322, 372), match='From: "carlos savimbi" <savimbicar1@dogmail.co.uk>
# <re.Match object; span=(193, 221), match='From: vumeh704@hknetmail.com'>
# <re.Match object; span=(76, 128), match='From: "CHIEF(DR.)BODE GEORGE" <bodegeorge@pisem.n>
# <re.Match object; span=(243, 285), match='From: mariam abachas <mariamabachs@go.com>'>
# <re.Match object; span=(187, 227), match='From: "ALI AHMED" <aliahmed@ecplaza.net>'>
# <re.Match object; span=(67, 112), match='From: "Abu Kyari." <akyari1@sudanmail.net.sd>'>
# <re.Match object; span=(187, 214), match='From: alimabu@tiscali.co.uk'>
# <re.Match object; span=(127, 175), match='From: "Joseph Savimbi" <joseph_1ang@zwallet.com>'>
# <re.Match object; span=(66, 114), match='From: "Joseph Savimbi" <joseph_1ang@zwallet.com>'>
# <re.Match object; span=(117, 160), match='From: "prince george duke" <naa8m@mail.com>'>
# <re.Match object; span=(124, 152), match='From: okijames@latinmail.com'>
# <re.Match object; span=(129, 185), match='From: "Mr. Jeffrey Daniels" <jeffreydaniels2@exci>
# <re.Match object; span=(128, 184), match='From: "Mr. Jeffrey Daniels" <jeffreydaniels4@exci>
# <re.Match object; span=(186, 227), match='From: "ADA USMAN!" <adausman@popmail.com>'>
# <re.Match object; span=(128, 172), match='From: "Daniel  Kargbu" <dankar3@zwallet.com>'>
# <re.Match object; span=(125, 169), match='From: "Mr. John Nlobo" <johnnlobo@yahoo.com>'>
# <re.Match object; span=(110, 142), match='From: <ajala8000@rediffmail.com>'>
# <re.Match object; span=(126, 174), match='From: "Dr.Kunle Owolo" <kunowolo3@tiscali.co.uk>'>
# <re.Match object; span=(129, 177), match='From: "Dr.Kunle Owolo" <kunowolo3@tiscali.co.uk>'>
# <re.Match object; span=(132, 185), match='From: "MRSJENNIFER KOBE" <mrsjennikobe@hknetmail.>
# <re.Match object; span=(66, 95), match='From: jackamala@tiscali.co.uk'>
# <re.Match object; span=(128, 172), match='From: "DR THOMAS AUDU" <thomasaudu@mail.com>'>
# <re.Match object; span=(211, 247), match='From: kalu idika <kaluidikak@go.com>'>
# <re.Match object; span=(162, 191), match='From: makalele01@xzapmail.com'>
# <re.Match object; span=(128, 154), match='From: g_ineh@tiscali.co.uk'>
# <re.Match object; span=(183, 243), match='From: "Michael Stevens Junior." <marksteven301@ne>
# <re.Match object; span=(188, 239), match='From: "Hajia Maryam Abacha" <maraba234@anfmail.co>
# <re.Match object; span=(190, 243), match='From: "Hajia Maryam Abacha" <maraba234@latinmail.>
# <re.Match object; span=(122, 174), match='From: "BARRISTER MATHEW IKE" <mathewike212@juno.c>
# <re.Match object; span=(192, 219), match='From: engedetamanah@post.cz'>
# <re.Match object; span=(186, 232), match='From: "MR.ODIASE GEORGE" <sunnyokogwo@post.cz>'>
# <re.Match object; span=(129, 176), match='From: "DEACON ZIK R. DON" <deacon_zik@yaoo.com>'>
# <re.Match object; span=(125, 169), match='From: "Nzanga Mobutu" <mobkuz3@kukamail.com>'>
# <re.Match object; span=(284, 308), match='From: adew1@mail3000.com'>
# <re.Match object; span=(240, 264), match='From: adew1@mail3000.com'>
# <re.Match object; span=(125, 178), match='From: "DR.MUHAMMED MUSTAFA" <muhammed303@arabtop.>
# <re.Match object; span=(183, 244), match='From: "BARRISTER, HOPKINS MBEKI" <hopkinsmbeki@hk>
# <re.Match object; span=(122, 149), match='From: ndandla@latinmail.com'>
# <re.Match object; span=(345, 373), match='From: <mcabacha@freesurf.fr>'>
# <re.Match object; span=(505, 545), match='From: "Mr Ugochukwu .W" <ugoch_8@z6.com>'>
# <re.Match object; span=(208, 239), match='From: shaabanbait@primposta.com'>
# <re.Match object; span=(68, 99), match='From: shaabanbait@primposta.com'>
# <re.Match object; span=(73, 109), match='From: consultant_ng3@send-mail.co.uk'>
# <re.Match object; span=(166, 198), match='From: mike odey <modey06@go.com>'>
# <re.Match object; span=(180, 228), match='From: "DR. AKIN DADA." <akindada@indiatimes.com>'>
# <re.Match object; span=(263, 320), match='From: "barrister vincent usman" <2003vincent@free>
# <re.Match object; span=(187, 231), match='From: "JAMIE  OPUKU." <jamie777@mail.biz.ly>'>
# <re.Match object; span=(255, 286), match='From: <jerrypeter2@freesurf.fr>'>
# <re.Match object; span=(169, 207), match='From: "mona noah" <mnoah3@hotmail.com>'>
# <re.Match object; span=(112, 151), match='From: "MICHEAL  OSSAI" <JUDE@YAHOO.COM>'>
# <re.Match object; span=(181, 201), match='From: test@yahoo.com'>
# <re.Match object; span=(57, 77), match='From: test@yahoo.com'>
# <re.Match object; span=(176, 217), match='From: "Peter Bongo" <mrbongo@themail.com>'>
# <re.Match object; span=(66, 117), match='From: MASTER HAROLD MBEKI <akumembeki@netscape.ne>
# <re.Match object; span=(69, 126), match='From: "maryaabacha8 maryam " <mmaryaabacha8@caram>
# <re.Match object; span=(69, 126), match='From: "maryaabacha8 maryam " <mmaryaabacha8@caram>
# <re.Match object; span=(132, 160), match='From: "H B" <hansob@123.com>'>
# <re.Match object; span=(251, 290), match='From: diaka tshombe <dtshombe2@123.com>'>
# <re.Match object; span=(192, 239), match='From: EKONG BASSEY <ekong.bassey2@caramail.com>'>
# <re.Match object; span=(172, 210), match='From: Vasil Nanchev <vas_imoti@abv.bg>'>
# <re.Match object; span=(176, 217), match='From: frank okonjo <frankokonjo5@123.com>'>
# <re.Match object; span=(189, 240), match='From: "DR. GODWIN KALALA" <gokalala1@tiscali.co.u>
# <re.Match object; span=(192, 239), match='From: EKONG BASSEY <ekong.bassey2@caramail.com>'>
# <re.Match object; span=(377, 427), match='From: HELLEN SHAKA ZUMA <hellenshaka@netscape.net>
# <re.Match object; span=(171, 210), match='From: Akande fredrick <fredsam@123.com>'>
# <re.Match object; span=(126, 171), match='From: esama kingdom <esamakingdom@fsmail.net>'>
# <re.Match object; span=(268, 306), match='From: MARY ABASS <mary_abass2@123.com>'>
# <re.Match object; span=(176, 217), match='From: frank okonjo <frankokonjo6@123.com>'>
# <re.Match object; span=(174, 215), match='From: "vino koni" <vinokoni5@hotmail.com>'>
# <re.Match object; span=(126, 157), match='From: sarah.mutete@caramail.com'>
# <re.Match object; span=(117, 163), match='From: "DAVIDS ANDERSON." <anders01_lb@post.cz>'>
# <re.Match object; span=(217, 256), match='From: diaka tshombe <dtshombe3@123.com>'>
# <re.Match object; span=(167, 195), match='From: markedeozo@freesurf.fr'>
# <re.Match object; span=(177, 207), match='From: abu_saeed4@tiscali.co.uk'>
# <re.Match object; span=(270, 294), match='From: elosub@freesurf.fr'>
# <re.Match object; span=(176, 223), match='From: "Yetunde Bassey" <yetunde@mail2world.com>'>
# <re.Match object; span=(176, 223), match='From: "Yetunde Bassey" <yetunde@mail2world.com>'>
# <re.Match object; span=(76, 124), match='From: "lary kamokai" <lary_kamokai1@hotmail.com>'>
# <re.Match object; span=(176, 229), match='From: "micheal ado santigo" <micheal_ado@hotmail.>
# <re.Match object; span=(354, 382), match='From: <fredkuma@freesurf.fr>'>
# <re.Match object; span=(131, 163), match='From: wolny_olkusz@latinmail.com'>
# <re.Match object; span=(137, 207), match='From: "DR. George Ibrahim Quattara" <dr_georgequa>
# <re.Match object; span=(130, 180), match='From: "Mr..John Chukwu" <johnchukwu1@caramail.com>
# <re.Match object; span=(71, 125), match='From: "DR BELLO BATURE" <dr.bell_bat@portugalmail>
# <re.Match object; span=(69, 126), match='From: "maryaabacha8 maryam " <mmaryaabacha8@caram>
# <re.Match object; span=(126, 178), match='From: "Mrs. Juliet Bello." <ladyj4u@mail2cherry.c>
# <re.Match object; span=(130, 186), match='From: "Mrs. Serena  Jones" <serenajones$$7@netsca>
# <re.Match object; span=(129, 180), match='From: "chuks Anthony" <chuksanthony05@netscape.ne>
# <re.Match object; span=(136, 198), match='From: =?us-ascii?Q?jide=20williams?= <jide.willia>
# <re.Match object; span=(63, 89), match='From: yinkadavi@mailbox.hu'>
# <re.Match object; span=(127, 169), match='From: "MR.WILLIAM" <william_d@zwallet.com>'>
# <re.Match object; span=(64, 106), match='From: "MR.WILLIAM" <william_d@zwalley.com>'>
# <re.Match object; span=(130, 160), match='From: karimusesay@whipmail.com'>
# <re.Match object; span=(132, 167), match='From: chesson_joseph@mail2world.com'>
# <re.Match object; span=(131, 179), match='From: "Nelson Abia" <nelson_abia203@hotmail.com>'>
# <re.Match object; span=(245, 293), match='From: "MR ALI AMED" <prince_amed011@hotmail.com>'>
# <re.Match object; span=(67, 117), match='From: "muhammed abacha" <abamohammed@ananzi.co.za>
# <re.Match object; span=(128, 171), match='From: "HASSAN DIKO" <hassandiko@fsmail.net>'>
# <re.Match object; span=(127, 179), match='From: "OLUWATOBI E.BOYE" <oluwatobiboye@dcemail.c>
# <re.Match object; span=(128, 180), match='From: "OLUWATOBI E.BOYE" <oluwatobiboye@dcemail.c>
# <re.Match object; span=(132, 183), match='From: "Mr Nelson Abia" <nelson_abia203@hotmail.co>
# <re.Match object; span=(122, 163), match='From: "Fred Okoli" <redokoli42@yahoo.com>'>
# <re.Match object; span=(67, 116), match='From: "haji musa diya" <musa_diya@fastermail.com>>
# <re.Match object; span=(229, 278), match='From: "haji musa diya" <musa_diya@fastermail.com>>
# <re.Match object; span=(129, 195), match='From: "From: Mrs. Victoria Bucknor" <victoriabuck>
# <re.Match object; span=(71, 137), match='From: "From: Mrs. Victoria Bucknor" <victoriabuck>
# <re.Match object; span=(130, 196), match='From: "From: Mrs. Victoria Bucknor" <victoriabuck>
# <re.Match object; span=(130, 196), match='From: "From: Mrs. Victoria Bucknor" <victoriabuck>
# <re.Match object; span=(131, 179), match='From: Mrs Serena Jones <ssarejo355@netscape.net>'>
# <re.Match object; span=(101, 133), match='From: "prince duke" <aa44@rt.nl>'>
# <re.Match object; span=(192, 244), match='From: "MRS M. SESE SEKO" <nanaseko3@web-mail.com.>
# <re.Match object; span=(135, 194), match='From: Mac Jonson Bonida <jonsonbonida_mac$77@lati>
# <re.Match object; span=(131, 181), match='From: "Mrs.Floxy Page" <floxypage44@hknetmail.com>
# <re.Match object; span=(120, 162), match='From: "PETER OKOYE" <opeter6@caramail.com>'>
# <re.Match object; span=(120, 162), match='From: "PETER OKOYE" <opeter6@caramail.com>'>
# <re.Match object; span=(111, 159), match='From: "MRS.MARYAM ABACHA" <firstlady234@post.cz>'>
# <re.Match object; span=(132, 184), match='From: "MRS M. SESE SEKO" <nanaseko4@web-mail.com.>
# <re.Match object; span=(283, 320), match='From: "MOHAMMED" <port1.net@email.it>'>
# <re.Match object; span=(285, 322), match='From: "MOHAMMED" <port1.net@email.it>'>
# <re.Match object; span=(285, 322), match='From: "MOHAMMED" <port1.net@email.it>'>
# <re.Match object; span=(121, 170), match='From: "HAJIA MARYAM ABACHA" <hajia2000@i2828.com>>
# <re.Match object; span=(122, 176), match='From: =?us-ascii?Q?mogua=20mogogo?= <moguam@sezna>
# <re.Match object; span=(86, 146), match='From: selina_gabrielmarinze <selina_gabrielmarinz>
# <re.Match object; span=(175, 205), match='From: y a <project101@123.com>'>
# <re.Match object; span=(133, 191), match='From: "MRS AMINA MOHAMMED" <aminamohammed311@nets>
# <re.Match object; span=(175, 211), match='From: MRS SUSAN <mrs_susan2@123.com>'>
# <re.Match object; span=(120, 184), match='From: "Dr.Faroq Uztaz[Regional Director]" <faroqz>
# <re.Match object; span=(121, 167), match='From: MR JANG DOO-HWAN <jangdo1@hknetmail.com>'>
# <re.Match object; span=(175, 211), match='From: ken dikko <kendikko01@123.com>'>
# <re.Match object; span=(118, 159), match='From: "Mr Ugochukwu" <ugochukwu_8@z6.com>'>
# <re.Match object; span=(109, 145), match='From: "from prince duke" <d11@rt.nl>'>
# <re.Match object; span=(102, 140), match='From: "from prince duke" <van77@rt.nl>'>
# <re.Match object; span=(113, 157), match='From: Thomas Taylor <thomutete@netscape.net>'>
# <re.Match object; span=(119, 163), match='From: "Mr.Michael Dohn" <m_doh4@zwallet.com>'>
# <re.Match object; span=(120, 164), match='From: "Mr.Michael Dohn" <m_doh4@zwallet.com>'>
# <re.Match object; span=(65, 93), match='From: jonbwaya@tiscali.co.uk'>
# <re.Match object; span=(65, 93), match='From: jonbwaya@tiscali.co.uk'>
# <re.Match object; span=(180, 226), match='From: william Isiaka <williamisiaka55@123.com>'>
# <re.Match object; span=(132, 190), match='From: "DR. MRS. MARIAM ABACHA" <hmariam234@rediff>
# <re.Match object; span=(130, 181), match='From: "MR MICHAEL EWALD" <mikeewald@eudoramail.co>
# <re.Match object; span=(165, 194), match='From: abayomidavies@yahoo.com'>
# <re.Match object; span=(109, 143), match='From: errol_marshall2@albawaba.com'>
# <re.Match object; span=(180, 228), match='From: mrsjane abdullah <mrsjaneabdullah@123.com>'>
# <re.Match object; span=(192, 233), match='From: Yetunde Bassey <yet_bassey@123.com>'>
# <re.Match object; span=(137, 194), match='From: "MOHAMMED ABACHA" <mohammedabacha000@tiscal>
# <re.Match object; span=(137, 194), match='From: "MOHAMMED ABACHA" <mohammedabacha000@tiscal>
# <re.Match object; span=(128, 175), match='From: "MOHAMMED ABACHA" <mohammed_ab000@go.com>'>
# <re.Match object; span=(134, 191), match='From: "MOHAMMED ABACHA" <mohammedabacha000@tiscal>
# <re.Match object; span=(137, 194), match='From: "MOHAMMED ABACHA" <mohammedabacha000@tiscal>
# <re.Match object; span=(125, 167), match='From: "MARK AKPU" <markakpu@tiscali.co.uk>'>
# <re.Match object; span=(265, 306), match='From: susan shabangu <sussy_shab@123.com>'>
# <re.Match object; span=(130, 187), match='From: "Mr. Nasser Nasiri." <nassernasiri2003@uaem>
# <re.Match object; span=(71, 128), match='From: "Mr. Nasser Nasiri." <nassernasiri2003@uaem>
# <re.Match object; span=(128, 185), match='From: "Mr. Nasser Nasiri." <nassernasiri2003@uaem>
# <re.Match object; span=(297, 322), match='From: sogolo_hmd@juno.com'>
# <re.Match object; span=(117, 148), match='From: "prince duke" <laa@rt.nl>'>
# <re.Match object; span=(126, 156), match='From: jrchesson@rediffmail.com'>
# <re.Match object; span=(129, 181), match='From: Mrs Serena Jones <serenajones1@rediffmail.c>
# <re.Match object; span=(128, 188), match='From: MR BASHE MOBUTU SESE SEKO <mobutbashe3@redi>
# <re.Match object; span=(67, 112), match='From: "PETER BUNO" <peterbuno@rediffmail.com>'>
# <re.Match object; span=(128, 173), match='From: "PETER BUNO" <peterbuno@rediffmail.com>'>
# <re.Match object; span=(66, 95), match='From: jeffmboma@tiscali.co.uk'>
# <re.Match object; span=(119, 175), match='From: "ABDULKAREEM USMAN" <abdulkareem_39@findolo>
# <re.Match object; span=(172, 210), match='From: "Mr. Duke Nze" <dukenze@123.com>'>
# <re.Match object; span=(172, 210), match='From: "Mr. Duke Nze" <dukenze@123.com>'>
# <re.Match object; span=(123, 167), match='From: "Phill Ipenza" <philpenza@ecplaza.com>'>
# <re.Match object; span=(132, 177), match='From: james kyari <jameskyari22@netscape.net>'>
# <re.Match object; span=(115, 159), match='From: "DR DONALD" <dr_don_ike@hknetmail.com>'>
# <re.Match object; span=(172, 210), match='From: mariama seseko <mmssko2@123.com>'>
# <re.Match object; span=(127, 189), match='From: "NETHERLOTTO CORPORATION." <netherlotto@cor>
# <re.Match object; span=(128, 174), match='From: "MR.DANDY NNAJI" <dandy_nnaji@yahoo.com>'>
# <re.Match object; span=(122, 168), match='From: "MR.DANDY NNAJI" <dandy_nnaji@yahoo.com>'>
# <re.Match object; span=(60, 104), match='From: "PETERSON BULINGA" <peson@zwallet.com>'>
# <re.Match object; span=(130, 195), match='From: MR JOSEPH MOBUTU SESE SEKO <josephmobutu200>
# <re.Match object; span=(118, 150), match='From: dada abu <dada@fsmail.net>'>
# <re.Match object; span=(192, 233), match='From: Yetunde Bassey <yet_bassey@123.com>'>
# <re.Match object; span=(195, 239), match='From: susan shubangu <susanshubangu@123.com>'>
# <re.Match object; span=(127, 174), match='From: kayode phillip <kayodephillip@fsmail.net>'>
# <re.Match object; span=(68, 119), match='From: Mrs Jumai YOUSSEF <juma2003@thepostbox.co.u>
# <re.Match object; span=(118, 157), match='From: "DR Peter Clapton" <wasa@was.com>'>
# <re.Match object; span=(55, 94), match='From: "DR Peter Clapton" <wasa@was.com>'>
# <re.Match object; span=(118, 157), match='From: "DR Peter Clapton" <wasa@was.com>'>
# <re.Match object; span=(113, 152), match='From: "DR Peter Clapton" <wasa@was.com>'>
# <re.Match object; span=(259, 298), match='From: Alexander Afadia <eeaesq@123.com>'>
# <re.Match object; span=(122, 164), match='From: "MUSA AHMED ZULU" <musma_adb@ny.com>'>
# <re.Match object; span=(258, 289), match='From: issacwimpoehato@yahoo.com'>
# <re.Match object; span=(177, 222), match='From: Mallam Bello Ali <mallam_bello@123.com>'>
# <re.Match object; span=(125, 168), match='From: james morgan <jamesmorgan@fsmail.net>'>
# <re.Match object; span=(235, 278), match='From: "Fred Okoli" <fredokoli300@yahoo.com>'>
# <re.Match object; span=(232, 275), match='From: "Fred Okoli" <fredokoli300@yahoo.com>'>
# <re.Match object; span=(235, 287), match='From: "MR.lucman Watson" <lucman_watson@macmail.c>
# <re.Match object; span=(262, 306), match='From: "KAZEEM AHMED" <kazeemahmed@gawab.com>'>
# <re.Match object; span=(262, 309), match='From: JULIET UGAGA <julietugaga22@netscape.net>'>
# <re.Match object; span=(203, 242), match='From: Frank Bello <fbello1@megamail.pt>'>
# <re.Match object; span=(201, 240), match='From: Frank Bello <fbello1@megamail.pt>'>
# <re.Match object; span=(128, 180), match='From: "MR FEMI MARTINS" <femi-martins876@fsmail.n>
# <re.Match object; span=(152, 213), match='From: "laurent_nkono@zwallet.com" <laurent_nkono@>
# <re.Match object; span=(133, 204), match='From: "MRS. MARIAM ABACHA (WIDOW)." <bonakama2323>
# <re.Match object; span=(128, 160), match='From: manuelsisilu@latinmail.com'>
# <re.Match object; span=(129, 183), match='From: "Mohammed Mustafa" <mohammedmustafa@arabtop>
# <re.Match object; span=(166, 199), match='From: abachafamily4@tiscali.co.uk'>
# <re.Match object; span=(203, 240), match='From: "THEMBI" <thembi79@zwallet.com>'>
# <re.Match object; span=(120, 154), match='From: kojadams <kojadams@voila.fr>'>
# <re.Match object; span=(125, 167), match='From: "Carl Eblon" <carleblon@zwallet.com>'>
# <re.Match object; span=(144, 186), match='From: "DAVIS TUTU" <davistutu@yahoo.co.uk>'>
# <re.Match object; span=(128, 171), match='From: "SAM KOROMA" <sarakoroma@hotmail.com>'>
# <re.Match object; span=(291, 319), match='From: "" <mjaja02@libero.it>'>
# <re.Match object; span=(153, 183), match='From: hildatoms@Eudoramail.com'>
# <re.Match object; span=(171, 213), match='From: "Rose Savimbi" <rosesav1@webave.com>'>
# <re.Match object; span=(153, 207), match='From: "From Mr Nelson Bidi ." <mrnelsonbidi_3@123>
# <re.Match object; span=(65, 119), match='From: "From Mr Nelson Bidi ." <mrnelsonbidi_3@123>
# <re.Match object; span=(122, 176), match='From: "From Mr Nelson Bidi ." <mrnelsonbidi_3@123>
# <re.Match object; span=(66, 95), match='From: usman_ali@tiscali.co.uk'>
# <re.Match object; span=(124, 166), match='From: henrich agah <hc_agah555@fsmail.net>'>
# <re.Match object; span=(124, 172), match='From: "FROM MRS RAMA IDRIS" <rama1@whipmail.com>'>
# <re.Match object; span=(125, 189), match='From: "FROM  PRINCE WILLIAMS  TAYOLR." <princewil>
# <re.Match object; span=(66, 130), match='From: "FROM  PRINCE WILLIAMS  TAYOLR." <princewil>
# <re.Match object; span=(137, 174), match='From: joseph.williamvaye@caramail.com'>
# <re.Match object; span=(127, 168), match='From: "collins" <collinsngobe@fsmail.net>'>
# <re.Match object; span=(66, 107), match='From: "collins" <collinsngobe@fsmail.net>'>
# <re.Match object; span=(144, 168), match='From: kaladah@epatra.com'>
# <re.Match object; span=(143, 191), match='From: "DR OKON PHILIP" <okphilip1@tiscali.co.uk>'>
# <re.Match object; span=(153, 201), match='From: "Donga Kabaka" <dongakabaka@tiscali.co.uk>'>
# <re.Match object; span=(123, 166), match='From: james momodu <Bruno.Daems@pandora.be>'>
# <re.Match object; span=(130, 186), match='From: "MR IBRAHIM YADUDU." <ibrahimyadudu@tiscali>
# <re.Match object; span=(144, 194), match='From: "DR. JOHNSON KENNETH" <jjoh3000@yahoo.co.uk>
# <re.Match object; span=(144, 194), match='From: "DR. JOHNSON KENNETH" <jjoh3000@yahoo.co.uk>
# <re.Match object; span=(181, 211), match='From: gregorykabila333@mail.bg'>
# <re.Match object; span=(224, 265), match='From: mary alade <maryalade66@fsmail.net>'>
# <re.Match object; span=(123, 163), match='From: K.M.ZONDI@foxfire.mr.itd.UM (REV),'>
# <re.Match object; span=(132, 187), match='From: "DANJUMA WILLIAMS M" <danjumawilliams@fsmai>
# <re.Match object; span=(123, 166), match='From: dr kabo hammed <ka_hammed@fsmail.net>'>
# <re.Match object; span=(124, 167), match='From: maryam abacha <mar_maryam@fsmail.net>'>
# <re.Match object; span=(124, 164), match='From: "KEN GOMAN" <ukpd@web-mail.com.ar>'>
# <re.Match object; span=(70, 103), match='From: mohameed_aba1@tiscali.co.uk'>
# <re.Match object; span=(69, 101), match='From: mohameed_aba@tiscali.co.uk'>
# <re.Match object; span=(202, 240), match='From: "george akin" <george2000@wp.pl>'>
# <re.Match object; span=(129, 174), match='From: robert harare <rharare1@spinfinder.com>'>
# <re.Match object; span=(69, 101), match='From: mohameed_aba@tiscali.co.uk'>
# <re.Match object; span=(121, 157), match='From: "J.C.G" <jocg102@netscape.net>'>
# <re.Match object; span=(322, 375), match='From: "oliver  yengeni" <oliveryengeni@tiscali.co>
# <re.Match object; span=(158, 198), match='From: kufor2000 <kufor2000@tatanova.com>'>
# ...
# <re.Match object; span=(247, 299), match='From: "Barrister Gareth Jones" <info@bebemous.co.>
# <re.Match object; span=(388, 449), match='From: "Edward Moore & Associates" <edwardmoore99@>
# <re.Match object; span=(272, 313), match='From: "Mr John Jasper" <johnp11@iwon.com>'>
# <re.Match object; span=(255, 307), match='From: marie ange attah <attahmarieange23@hotmail.>
# <re.Match object; span=(448, 510), match='From: "Edward Moore & Associates" <edward_moore22>
# <re.Match object; span=(450, 512), match='From: "Edward Moore & Associates" <edward_moore22>
# <re.Match object; span=(398, 460), match='From: "Edward Moore & Associates" <edward_moore22>
# <re.Match object; span=(252, 314), match='From: "Edward Moore & Associates" <edward_moore22>
# <re.Match object; span=(130, 179), match='From: Robert Williams <robertwills@pre.sltnet.lk>>
# <re.Match object; span=(190, 213), match='From: adnanhram@aim.com'>
# <re.Match object; span=(344, 392), match='From: Michael Jones <michjones@mickyjones.co.uk>'>
# <re.Match object; span=(240, 283), match='From: Koutaba jean <koutab0078@hotmail.com>'>
# <re.Match object; span=(230, 275), match='From: Phillip Croce <bullfrog812@charter.net>'>
# <re.Match object; span=(215, 265), match='From: asinthe nignan <asinthe_nignan33@hotmail.fr>
# <re.Match object; span=(130, 179), match='From: Robert Williams <robertwills@pre.sltnet.lk>>
# <re.Match object; span=(164, 188), match='From: emekaben@aol.co.uk'>
# <re.Match object; span=(339, 400), match='From: "Edward Moore & Associates" <edwardmoore99@>
# <re.Match object; span=(237, 283), match='From: "Mr. Gamudi Mboma" <gmboma2@hotmail.com>'>
# <re.Match object; span=(402, 452), match='From: mrcolinshand20 <mrcolinshand20@poczta.pf.pl>
# <re.Match object; span=(220, 272), match='From: richard bongo <richard_bongo112za@hotmail.c>
# <re.Match object; span=(220, 272), match='From: richard bongo <richard_bongo112za@hotmail.c>
# <re.Match object; span=(241, 284), match='From: Koutaba jean <koutab0025@hotmail.com>'>
# <re.Match object; span=(252, 300), match='From: DR AHMED SHALAA <drahmed_sh14@hotmail.com>'>
# <re.Match object; span=(291, 340), match='From: COLLINS LYONS <collins_lyons73@yahoo.co.uk>>
# <re.Match object; span=(140, 196), match='From: "Mr.Jonathan Mutambara" <rahim.attah1@virgi>
# <re.Match object; span=(395, 446), match='From: "FREDERICK WILLIAMS." <fred_williams05@o2.p>
# <re.Match object; span=(242, 284), match='From: amir jasmin <amija_1035@hotmail.com>'>
# <re.Match object; span=(94, 145), match='From: "Mahmud Azzam" <mamud_islandoil@yahoo.com.h>
# <re.Match object; span=(94, 145), match='From: "Mahmud Azzam" <mamud_islandoil@yahoo.com.h>
# <re.Match object; span=(151, 205), match='From: CHRIS ANDERSON <chris_anderson@universia.co>
# <re.Match object; span=(243, 285), match='From: ben coroma <bencoroma12@hotmail.com>'>
# <re.Match object; span=(261, 330), match='From: "MRS. LARISA SOSNITSKAYA" <larisasosnkayapa>
# <re.Match object; span=(165, 216), match='From: MR WILLIAM KABILA <williamkabila05@gmail.co>
# <re.Match object; span=(227, 285), match='From: LIKA CHEUNG HOLDINGS LIMITED <joemelosi@cha>
# <re.Match object; span=(186, 254), match='From: "MRS. LARISA SOSNITSKAYA" <larisasosnkayanx>
# <re.Match object; span=(405, 466), match='From: " MR james roberts" <james_roberts007@naveg>
# <re.Match object; span=(185, 232), match='From: "Dr. Paul A. Sule" <drpaulsule1950@o2.pl>'>
# <re.Match object; span=(245, 286), match='From: john alison <johnali20@hotmail.com>'>
# <re.Match object; span=(185, 230), match='From: "alimoheamed1" <alimoheamed1@mynet.com>'>
# <re.Match object; span=(236, 300), match='From: "Mr. Joseph Chau." <info_unionbankofchain00>
# <re.Match object; span=(142, 192), match='From: Mr Paul Baloyi <patrickokonta10@virgilio.it>
# <re.Match object; span=(142, 192), match='From: Mr Paul Baloyi <patrickokonta10@virgilio.it>
# <re.Match object; span=(253, 297), match='From: nabjib ibrahim <nabjib_n27@hotmail.fr>'>
# <re.Match object; span=(253, 297), match='From: nabjib ibrahim <nabjib_n27@hotmail.fr>'>
# <re.Match object; span=(278, 328), match='From: "Mr. Albert Sitholi" <sitholi@webmail.co.za>
# <re.Match object; span=(253, 308), match='From: fredrick thambo <fredrick.thambo.107@hotmai>
# <re.Match object; span=(251, 299), match='From: musa saladin <musa_saladin030@hotmail.com>'>
# <re.Match object; span=(146, 189), match='From: "PETER NDABA" <peterndaba@fsmail.net>'>
# <re.Match object; span=(157, 180), match='From: kouajo@hotmail.fr'>
# <re.Match object; span=(311, 358), match='From: "DR DAVID RAY" <david_ray202@yahoo.co.uk>'>
# <re.Match object; span=(292, 327), match='From: JOHN ABOH <meetic@meetic.com>'>
# <re.Match object; span=(263, 314), match='From: "Mikhail Khodorkovsky" <mikhail@yukosoil.co>
# <re.Match object; span=(149, 175), match='From: koajoo_aka@yahoo.com'>
# <re.Match object; span=(256, 302), match='From: theresa coleman <mrst5heresa@hotmail.fr>'>
# <re.Match object; span=(590, 634), match='From: JOSEPH hOPONU <hoponuj101@yahoo.co.jp>'>
# <re.Match object; span=(290, 346), match='From: "A.B. Solarin" <alexandro_solarin1973@yahoo>
# <re.Match object; span=(277, 324), match='From: "Martins Mazuri" <mart_mazuri03@yahoo.ca>'>
# <re.Match object; span=(242, 287), match='From: "Mr. Peter Leon" <mr66leon@hotmail.com>'>
# <re.Match object; span=(251, 303), match='From: chantal kouakou <kouakou_chantou15@hotmail.>
# <re.Match object; span=(251, 303), match='From: chantal kouakou <kouakou_chantou15@hotmail.>
# <re.Match object; span=(214, 260), match='From: sahidi ngoma <sahidi_ngoma14@hotmail.fr>'>
# <re.Match object; span=(159, 216), match='From: Capt James C Willians <officialmail@realmai>
# <re.Match object; span=(338, 365), match='From: "IRS"<refund@irs.gov>'>
# <re.Match object; span=(125, 171), match='From: "MR. MARK ADAMS" <m_adams1102@walla.com>'>
# <re.Match object; span=(125, 171), match='From: "MR. MARK ADAMS" <m_adams1102@walla.com>'>
# <re.Match object; span=(300, 346), match='From: "bala kabore" <bala_kabore48@hotmail.fr>'>
# <re.Match object; span=(134, 178), match='From: "DR.IDRISSA SEKK" <d_dudu@virgilio.it>'>
# <re.Match object; span=(250, 296), match='From: gerald zongo <geraldzongo_38@hotmail.fr>'>
# <re.Match object; span=(241, 284), match='From: chantal kouakou <chant004@hotmail.fr>'>
# <re.Match object; span=(260, 315), match='From: princess gesinta <princess_gesinta016@hotma>
# <re.Match object; span=(140, 189), match='From: MR JAMES ROBERTS <williambrown@virgilio.it>>
# <re.Match object; span=(326, 366), match='From: Tim McCarron <pre91@pre.sltnet.lk>'>
# <re.Match object; span=(132, 194), match='From: "Chief Anthony Enahoro. JP" <coalition_prot>
# <re.Match object; span=(120, 167), match='From: "Richard Akintunde"<r.akintunde@yahoo.it>'>
# <re.Match object; span=(321, 367), match='From: "Martins Akim" <martinsakim@handbag.com>'>
# <re.Match object; span=(402, 450), match='From: "Dr. Ahmed Hassan" <ahassan1696@gmail.com>'>
# <re.Match object; span=(402, 450), match='From: "Dr. Ahmed Hassan" <ahassan1696@gmail.com>'>
# <re.Match object; span=(120, 162), match='From: "LUISA ESTRADA" <luisa@blue-conn.de>'>
# <re.Match object; span=(140, 202), match='From: "Evangelist Lindy Mike (Widow)." <evlindymi>
# <re.Match object; span=(301, 361), match='From: "Edward Moore & Associates" <edward.moore20>
# <re.Match object; span=(302, 364), match='From: "Edward Moore & Associates" <edward.moore99>
# <re.Match object; span=(287, 329), match='From: "bjsri budak" <bjsri072@hotmail.com>'>
# <re.Match object; span=(349, 412), match='From: Barrister Al Mohammed El Said <benmowilliam>
# <re.Match object; span=(142, 189), match='From: Gary William <stella.sigcau4@virgilio.it>'>
# <re.Match object; span=(139, 191), match='From: "Mr. Robin Shephard" <fredmaxwell@virgilio.>
# <re.Match object; span=(141, 194), match='From: "Martin J. Waghorn" <leonardmuller@virgilio>
# <re.Match object; span=(320, 366), match='From: "Didan Kimati" <kimati_didan@excite.com>'>
# <re.Match object; span=(243, 292), match='From: MR LAAD cologo <mrlaad_cologo13@hotmail.fr>>
# <re.Match object; span=(89, 118), match='From: harryugo@zipmail.com.br'>
# <re.Match object; span=(239, 275), match='From: mike kone <mikkon5@hotmail.fr>'>
# <re.Match object; span=(166, 205), match='From: "Dave Yorke." <dyorke@freenet.de>'>
# <re.Match object; span=(248, 297), match='From: "Mrs  Farah Al-hashemi" <msalhak@yahoo.com>>
# <re.Match object; span=(260, 309), match='From: "Mrs  Farah Al-hashemi" <msalhak@yahoo.com>>
# <re.Match object; span=(320, 363), match='From: Eric Johnson <ericjohnson6@myway.com>'>
# <re.Match object; span=(214, 260), match='From: sahidi ngoma <sahidi_ngoma13@hotmail.fr>'>
# <re.Match object; span=(463, 501), match='From: mike kone <mikeko018@hotmail.fr>'>
# <re.Match object; span=(242, 284), match='From: tony anthony <tonywach4@hotmail.com>'>
# <re.Match object; span=(179, 231), match='From: PROF CHARLES SOLUDO <mrsbakare@rediffmail.c>
# <re.Match object; span=(249, 279), match='From: urgentmatter@sunumail.sn'>
# <re.Match object; span=(410, 462), match='From: "REV.WILSON MORGAN" <inheritance_fund00@o2.>
# <re.Match object; span=(409, 461), match='From: "REV.WILSON MORGAN" <inheritance_fund00@o2.>
# <re.Match object; span=(251, 282), match='From: janetbradford@sunumail.sn'>
# <re.Match object; span=(142, 189), match='From: Gary William <stella.sigcau4@virgilio.it>'>
# <re.Match object; span=(455, 517), match='From: "Mr Aphisak Tantiworawong" <aphisak.project>
# <re.Match object; span=(341, 384), match='From: J_KEMPWELCH01 <jkemp1968@yahoo.co.uk>'>
# <re.Match object; span=(463, 515), match='From: "Mr.Morgan Wimpoe" <morgan.wimpoe01@yahoo.c>
# <re.Match object; span=(127, 157), match='From: <alima_kkk10@centrum.cz>'>
# <re.Match object; span=(223, 266), match='From: "Adekunle michael." <dmike0013@o2.pl>'>
# <re.Match object; span=(505, 542), match='From: QIN LI WANG <buddycrk@fuse.net>'>
# <re.Match object; span=(251, 298), match='From: idris makafi <idris_makafi167@hotmail.fr>'>
# <re.Match object; span=(315, 364), match='From: "DR. CLEMENT ASUZU" <clementasuzu@yahoo.it>>
# <re.Match object; span=(205, 240), match='From: emma tano <ball16@hotmail.fr>'>
# <re.Match object; span=(231, 282), match='From: "Bank of America" <Banking@Bankofamerica.co>
# <re.Match object; span=(411, 454), match='From: Mou Xinsheng <spiritsanct@onetel.com>'>
# <re.Match object; span=(156, 219), match='From: "Prof.Charles.C.Soludo" <cbnpayment.org@hos>
# <re.Match object; span=(398, 427), match='From: matinread@turbonett.com'>
# <re.Match object; span=(364, 408), match='From: "jen_marthin" <jen_marthin@centrum.sk>'>
# <re.Match object; span=(313, 365), match='From: "aziz moustafa" <aziz_moustafa100@hotmail.c>
# <re.Match object; span=(243, 275), match='From: MM BB <mbd095@hotmail.com>'>
# <re.Match object; span=(88, 141), match='From: "Mrs Farah al-Hashemi" <mrsfarah30@yahoo.co>
# <re.Match object; span=(256, 308), match='From: kanazoe alidaa <kanazoe_alidaa0007@hotmail.>
# <re.Match object; span=(258, 306), match='From: williams susan <wil_li_net0064@hotmail.fr>'>
# <re.Match object; span=(185, 229), match='From: "bajoga bajoga" <bajoga@latinmail.com>'>
# <re.Match object; span=(309, 353), match='From: "Robert Zulugan." <rubzuul@freenet.de>'>
# <re.Match object; span=(88, 142), match='From: "Mrs. Farah al-Hashemi" <mrsfarah30@yahoo.c>
# <re.Match object; span=(165, 206), match='From: Jaron Abbas <jaron_abbass@yahoo.de>'>
# <re.Match object; span=(165, 206), match='From: Jaron Abbas <jaron_abbass@yahoo.de>'>
# <re.Match object; span=(245, 288), match='From: adams swill <adams5swill@hotmail.com>'>
# <re.Match object; span=(161, 206), match='From: susan  john <susan_john203@yahoo.co.uk>'>
# <re.Match object; span=(189, 241), match='From: "GOBLOUSO SOLANGE " <gosolanges@latinmail.c>
# <re.Match object; span=(244, 297), match='From: Prince David Djedjess <djedjess007@hotmail.>
# <re.Match object; span=(249, 296), match='From: adams kabora <adams_kabora11@hotmail.com>'>
# <re.Match object; span=(249, 296), match='From: adams kabora <adams_kabora31@hotmail.com>'>
# <re.Match object; span=(254, 313), match='From: "Christopher  Wilson" <christopherwilson@su>
# <re.Match object; span=(728, 745), match='From:Sarat Hassan'>
# <re.Match object; span=(222, 254), match='From: <chantalveroniq2@yahoo.fr>'>
# <re.Match object; span=(121, 156), match='From: JOHN HILL <johnhill87@aol.fr>'>
# <re.Match object; span=(186, 235), match='From: CAROL HARVEY <esoil_gasltd231@yahoo.com.hk>>
# <re.Match object; span=(450, 503), match='From: isedore lawan <mr_isedore_lawan0053@hotmail>
# <re.Match object; span=(268, 324), match='From: "Mr A.B Solarino" <benjaminosolarin4u@yahoo>
# <re.Match object; span=(247, 296), match='From: HARRISON FELISSA <felissajen115@hotmail.fr>>
# <re.Match object; span=(138, 184), match='From: MR NELSON BROWN <mrscarolyn@virgilio.it>'>
# <re.Match object; span=(427, 484), match='From: "Sunoco Sun Oil Company Ltd" <onlineli@phre>
# <re.Match object; span=(427, 484), match='From: "Sunoco Sun Oil Company Ltd" <onlineli@phre>
# <re.Match object; span=(254, 301), match='From: joel thomson <joelthomson804@hotmail.com>'>
# <re.Match object; span=(245, 293), match='From: HANG SENG BANK <peter@hangsengbank.com.hk>'>
# <re.Match object; span=(119, 159), match='From: "Steven Lee"<stevnlee010@sify.com>'>
# <re.Match object; span=(124, 151), match='From: <ch_20007@centrum.cz>'>
# <re.Match object; span=(404, 453), match='From: LIUYANMAILPOST <liuyan_office@yahoo.com.hk>>
# <re.Match object; span=(285, 334), match='From: "MR. KENNETH MASHABA" <kmashaba1@myway.com>>
# <re.Match object; span=(395, 452), match='From: "The SHIGA BANK LTD" <ooxxee.ooxxeee03@lapo>
# <re.Match object; span=(326, 377), match='From: "Louis (Business).." <femirhodes@virgilio.i>
# <re.Match object; span=(390, 447), match='From: "The SHIGA BANK LTD" <ooxxee.ooxxeee03@lapo>
# <re.Match object; span=(289, 337), match='From: "MRS. ANNAH KRUGA" <a_annah50@hotmail.com>'>
# <re.Match object; span=(264, 289), match='From: nafmohd101@yahoo.fr'>
# <re.Match object; span=(207, 282), match='From: "julia.chen.shenhua.group@hotmail.com" <oox>
# <re.Match object; span=(243, 291), match='From: nelson mansuguri <mansuguri63@hotmail.com>'>
# <re.Match object; span=(243, 284), match='From: kali oddo <kali_oddo017@hotmail.fr>'>
# <re.Match object; span=(196, 251), match='From: "james bongani" <jamesbongani10015@latinmai>
# <re.Match object; span=(210, 248), match='From: us zongo <us_zongo35@hotmail.fr>'>
# <re.Match object; span=(159, 205), match='From: Vincent Cheung <gladvince01@yahoo.co.uk>'>
# <re.Match object; span=(213, 267), match='From: "BARR.JONATHAN WRIGHT" <wrightchember@gmail>
# <re.Match object; span=(159, 202), match='From: petertaylor <petertayloruk2@yahoo.de>'>
# <re.Match object; span=(125, 166), match='From: Jaron Abbas <jaron_abbass@yahoo.de>'>
# <re.Match object; span=(243, 285), match='From: patrick jombo <mrjombo23@hotmail.fr>'>
# <re.Match object; span=(242, 280), match='From: abl musa <ablmusa_03@hotmail.fr>'>
# <re.Match object; span=(142, 195), match='From: "Dr. David Smith" <dickson_robert1@virgilio>
# <re.Match object; span=(248, 291), match='From: IDRIS ADAMU <idris40adamu@hotmail.fr>'>
# <re.Match object; span=(244, 288), match='From: KENNETH OBI <kennethobia5@hotmail.com>'>
# <re.Match object; span=(155, 199), match='From: "HENRY ALLEN" <henryallenci@seznam.cz>'>
# <re.Match object; span=(301, 340), match='From: Mr John Davids <mobeef@birch.net>'>
# <re.Match object; span=(301, 346), match='From: Khaled Bin al- Walid <mobeef@birch.net>'>
# <re.Match object; span=(253, 307), match='From: Mother Doris Killam <motherdorisk93@hotmail>
# <re.Match object; span=(197, 246), match='From: "Fernando Gonzalez" <best.list@laposte.net>>
# <re.Match object; span=(139, 204), match='From: "From: Dr. Jackson Gaius-Obaseki" <tony_ese>
# <re.Match object; span=(95, 130), match='From: michealagu0255@zipmail.com.br'>
# <re.Match object; span=(251, 294), match='From: ali sherif <ali_sherif252@hotmail.fr>'>
# <re.Match object; span=(254, 314), match='From: Dr Usman Ibrahim Danko <drusmanibrahimtg08@>
# <re.Match object; span=(165, 219), match='From: Mother Doris Killam <motherdorisk61@hotmail>

# %%
emails_df = pd.DataFrame(emails)
emails_df.head(10)
# Out:
#                     sender_email             sender_name  \
# 0    james_ngola2002@maktoob.com         MR. JAMES NGOLA
# 1   bensul2004nng@spinfinder.com         Mr. Ben Suleman
# 2           obong_715@epatra.com      PRINCE OBONG ELEME
# 3           obong_715@epatra.com      PRINCE OBONG ELEME
# 4             m_abacha03@www.com           Maryam Abacha
# 5         davidkuta@postmark.net              Kuta David
# 6         tunde_dosumu@lycos.com  Barrister tunde dosumu
# 7  william2244drallo@maktoob.com          William Drallo
# 8       abdul_817@rediffmail.com          MR USMAN ABDUL
# 9         barrister_td@lycos.com           Tunde  Dosumu
#
#         recipient_email recipient_name    date_sent  \
# 0  webmaster@aclweb.org      webmaster  31 Oct 2002
# 1                   R@M              R  31 Oct 2002
# 2  webmaster@aclweb.org      webmaster  31 Oct 2002
# 3  webmaster@aclweb.org      webmaster  31 Oct 2002
# 4                   R@M              R   1 Nov 2002
# 5   davidkuta@yahoo.com      davidkuta  02 Nov 2002
# 6                  None           None         None
# 7  webmaster@aclweb.org      webmaster   3 Nov 2002
# 8                   R@M              R  04 Nov 2002
# 9                  None           None         None
#
#                                        subject
# 0   URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# 1          URGENT ASSISTANCE /RELATIONSHIP (P)
# 2                              GOOD DAY TO YOU
# 3                              GOOD DAY TO YOU
# 4                      I Need Your Assistance.
# 5                                  Partnership
# 6                             Urgent Attention
# 7                      URGENT BUSINESS PRPOSAL
# 8                                    THANK YOU
# 9                            Urgent Assistance

# %%
emails_df.to_csv(f"{student1_section}_{student1_BN}_{student2_section}_{student2_BN}.csv", index=False)
